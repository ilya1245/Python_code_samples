# %%
# Code from https://www.youtube.com/watch?v=-CMhzgFbEtg&list=PLxgDUj5eygKnSd4MYHIuAC7E3VEPm_WLO&index=14
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(100, 2)
plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1]);

# %%
X = np.random.randn(200, 2)
X[:30] += 3
C = np.zeros(200)
C[:30] = 1
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=C);
