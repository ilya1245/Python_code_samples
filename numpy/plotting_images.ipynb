# %%
# Code from https://www.youtube.com/watch?v=PNTydM_geE4&list=PLxgDUj5eygKnSd4MYHIuAC7E3VEPm_WLO&index=16
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('c:/tmp/data/img_align_celeba_10000/000001.jpg')
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.array(img)
arr.shape
# Out:
# (218, 178, 3)

# %%
arr
# Out:
# array([[[253, 231, 194],
#         [253, 231, 194],
#         [253, 231, 194],
#         ...,
#         [246, 228, 216],
#         [255, 237, 223],
#         [254, 238, 222]],
#
#        [[253, 231, 194],
#         [253, 231, 194],
#         [253, 231, 194],
#         ...,
#         [248, 230, 218],
#         [255, 237, 223],
#         [254, 238, 222]],
#
#        [[253, 231, 194],
#         [253, 231, 194],
#         [253, 231, 194],
#         ...,
#         [250, 232, 220],
#         [255, 238, 224],
#         [255, 239, 223]],
#
#        ...,
#
#        [[140,  74,  26],
#         [115,  49,   1],
#         [146,  78,  33],
#         ...,
#         [122,  55,  28],
#         [123,  56,  30],
#         [122,  56,  30]],
#
#        [[130,  62,  15],
#         [138,  70,  23],
#         [166,  98,  53],
#         ...,
#         [118,  49,  20],
#         [120,  50,  24],
#         [118,  51,  24]],
#
#        [[168, 100,  53],
#         [204, 136,  89],
#         [245, 177, 132],
# ...

# %%
plt.imshow(arr);

# %%
plt.imshow(img);

# %%
gray = arr.mean(axis=2)
plt.imshow(gray);

# %%
plt.imshow(gray, cmap='gray');
