# %%
# Code from https://www.youtube.com/watch?v=C2FPN8RCDWw&list=PLxgDUj5eygKnSd4MYHIuAC7E3VEPm_WLO&index=15
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(10000) # normal
plt.hist(X);

# %%
plt.hist(X, bins=50);

# %%
X = np.random.random(10000) # uniform
plt.hist(X, bins=50);

# %%
X = np.random.uniform(0, 1, 1000) # uniform
plt.hist(X, bins=10);
